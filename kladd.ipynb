# %%
import matplotlib.pyplot as plt 
import numpy as np 

plt.style.use("custom_style/test.mplstyle")
# Out:
# Bad value in file 'custom_style/test.mplstyle', line 12 ('axes.edgecolor: rgba(231,229,228, .1)'): Key axes.edgecolor: 'rgba(231,229,228, .1)' does not look like a color arg
#
# Bad key axes.spines.left.set_alpha in file custom_style/test.mplstyle, line 14 ('axes.spines.left.set_alpha: .1')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.2/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution

# %%
y = np.random.normal(1, size=200)
x = np.linspace(-3,3, len(y))
# plt.style.use({"axes.edgecolor": "brown"})

fig, ax = plt.subplots()

ax.spines["left"].set_alpha(.5)
ax.spines["bottom"].set_alpha(.5)

ax.scatter(x,y)
ax.set(title="testing custom stylesheet")
# Out:
# [Text(0.5, 1.0, 'testing custom stylesheet')]
